# %% [markdown]
# # 📚 BÀI TẬP 1: SQL CƠ BẢN
#
# ## Mục tiêu học tập:
# - SELECT, WHERE, ORDER BY
# - LIMIT, OFFSET
# - Filtering với AND, OR, IN, BETWEEN
# - Pattern matching với LIKE
# - NULL handling

# %%
# Setup connection
import psycopg2
import pandas as pd
import os

def get_connection():
    return psycopg2.connect(
        host='postgres',
        port=5432,
        database='data_engineer',
        user='dataengineer',
        password='dataengineer123'
    )

def run_query(query):
    conn = get_connection()
    df = pd.read_sql_query(query, conn)
    conn.close()
    return df

print("✅ Connection setup ready!")
# Out:
# ✅ Connection setup ready!

# %% [markdown]
# ---
# ## 🎯 EXERCISE 1: SELECT cơ bản
#
# **Câu hỏi:** Lấy 10 customers đầu tiên, hiển thị tên, email và country

# %%
# YOUR CODE HERE
query = """
SELECT 
    customer_name,
    email,
    country
FROM analytics.customers
LIMIT 10;
"""

result = run_query(query)
print(f"📊 Found {len(result)} customers")
result
# Out:
# 📊 Found 10 customers
# /tmp/ipykernel_948/1579633788.py:17: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, conn)
#        customer_name                         email                country
# 0    Timothy Vincent           maria99@example.org             Azerbaijan
# 1  Edward Williamson      mcdonaldlisa@example.com               Anguilla
# 2       Jessica Reed            sdavis@example.net               Thailand
# 3       Carrie Davis      taylorleslie@example.org          Cote d'Ivoire
# 4        Rita Fuller  gonzalezsamantha@example.org                 Greece
# 5      Kyle Mckinney          nicole67@example.net  Sao Tome and Principe
# 6  Jeremiah Mcdonald           amartin@example.net                  Italy
# 7    Jennifer Martin          ifreeman@example.net         Cayman Islands
# ...

# %% [markdown]
# ---
# ## 🎯 EXERCISE 2: WHERE filtering
#
# **Câu hỏi:** Tìm tất cả customers ở Vietnam

# %%
# YOUR CODE HERE
query = """
SELECT 
    customer_name,
    email,
    country,
    customer_segment
FROM analytics.customers
WHERE country = 'Vietnam';
"""

result = run_query(query)
print(f"📊 Found {len(result)} customers from Vietnam")
result.head()
# Out:
# 📊 Found 2 customers from Vietnam
# /tmp/ipykernel_948/1579633788.py:17: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, conn)
#      customer_name                   email  country customer_segment
# 0  Brendan Hawkins    tracey80@example.org  Vietnam          Premium
# 1   Jasmin Johnson  haileyking@example.com  Vietnam         Standard

# %% [markdown]
# ---
# ## 🎯 EXERCISE 3: Multiple conditions
#
# **Câu hỏi:** Tìm Premium customers ở Vietnam hoặc USA

# %%
# YOUR CODE HERE
query = """
-- Write your query here
"""

result = run_query(query)
result.head()

# %% [markdown]
# ---
# ## 🎯 EXERCISE 4: Date filtering
#
# **Câu hỏi:** Tìm customers đăng ký trong năm 2024

# %%
# YOUR CODE HERE
query = """
-- Write your query here
"""

result = run_query(query)
result.head()

# %% [markdown]
# ---
# ## 🎯 EXERCISE 5: ORDER BY
#
# **Câu hỏi:** Top 10 orders có total_amount cao nhất

# %%
# YOUR CODE HERE
query = """
-- Write your query here
"""

result = run_query(query)
result

# %% [markdown]
# ---
# ## 🎯 EXERCISE 6: LIKE pattern matching
#
# **Câu hỏi:** Tìm products có tên chứa từ 'data'

# %%
# YOUR CODE HERE
query = """
-- Write your query here
"""

result = run_query(query)
result.head()

# %% [markdown]
# ---
# ## 🎯 EXERCISE 7: BETWEEN
#
# **Câu hỏi:** Tìm products có giá từ $100 đến $500

# %%
# YOUR CODE HERE
query = """
-- Write your query here
"""

result = run_query(query)
result.head()

# %% [markdown]
# ---
# ## 🎯 EXERCISE 8: IN operator
#
# **Câu hỏi:** Tìm orders có status là 'completed' hoặc 'pending'

# %%
# YOUR CODE HERE
query = """
-- Write your query here
"""

result = run_query(query)
print(f"📊 Found {len(result)} orders")
result.head()

# %% [markdown]
# ---
# ## 🎯 CHALLENGE: Complex query
#
# **Câu hỏi:** Tìm top 20 orders:
# - Status = 'completed'
# - Total amount > $1000
# - Order date trong Q4 2024
# - Sắp xếp theo total_amount giảm dần

# %%
# YOUR CODE HERE
query = """
-- Write your query here
"""

result = run_query(query)
result

# %% [markdown]
# ---
# ## 📊 SOLUTIONS
#
# Uncomment để xem đáp án

# %%
# # SOLUTION 2: WHERE filtering
# query = """
# SELECT 
#     customer_name,
#     email,
#     country,
#     customer_segment
# FROM analytics.customers
# WHERE country = 'Vietnam';
# """

# # SOLUTION 3: Multiple conditions
# query = """
# SELECT *
# FROM analytics.customers
# WHERE customer_segment = 'Premium'
#   AND country IN ('Vietnam', 'United States');
# """

# # SOLUTION 4: Date filtering
# query = """
# SELECT *
# FROM analytics.customers
# WHERE signup_date >= '2024-01-01'
#   AND signup_date < '2025-01-01';
# """

# # SOLUTION 5: ORDER BY
# query = """
# SELECT 
#     order_id,
#     customer_id,
#     order_date,
#     total_amount
# FROM analytics.orders
# ORDER BY total_amount DESC
# LIMIT 10;
# """

# # SOLUTION 8: CHALLENGE
# query = """
# SELECT 
#     order_id,
#     customer_id,
#     order_date,
#     total_amount,
#     order_status
# FROM analytics.orders
# WHERE order_status = 'completed'
#   AND total_amount > 1000
#   AND order_date >= '2024-10-01'
#   AND order_date < '2025-01-01'
# ORDER BY total_amount DESC
# LIMIT 20;
# """
